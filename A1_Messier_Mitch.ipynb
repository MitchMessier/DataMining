# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# # Task II

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='r', alpha=.3)

plt.xlabel("time")
plt.ylabel("amount")

plt.title("A simple line graph")
plt.show()

# %% [markdown]
# # Task III

# %% [markdown]
# **Task III Response:** With the graph above, I changed mutliple aspects to the following code. First, I added x and y axis labels. Adding "time" and "amount" allows the reader to easily follow what is happening within the graph and give more context to the visualization. Secound, I changed the alpha of the graph which essentially changes the transparency of the image. A higher number creates a darker, more appealing color, and vice versa for a lower number. Last, I altered the color from green to red. Altogether, those were the changes I made to the graph.

# %% [markdown]
# # Task IV

# %%
import pandas as pd

a1_data = pd.read_csv("https://raw.githubusercontent.com/matthewpecsok/4482_fall_2022/main/data/assignment_1.csv")
print(a1_data.head(8))
# Out:
#    customer_id  sale_amount category
# 0            4      5345.23        A
# 1            3       534.65        B
# 2            5       456.87        A
# 3            6       987.99        B
# 4            2        53.14        A
# 5            1      2325.23        B
# 6            9      7657.65        A
# 7           10          NaN        C

# %% [markdown]
# # Task V

# %%
a1_data.shape
# Out:
# (8, 3)

# %%
a1_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  8 non-null      int64
#  1   sale_amount  7 non-null      float64
#  2   category     8 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 320.0+ bytes

# %% [markdown]
# **Data Type Description:** There are a total of 8 rows and 3 columns within the data set. The three columns consist of three sperate data types: customer_id = integers, sale_amount = float/decimals, and category = object (used to store strings). Therefore there are two numeric columns and one string object. Additionally, there is one "null" value and is expressed as "NaN" in the data set. It is located within the sale amount column under Customer ID = 10. This means that there was no value entered within that cell. This can affect calcuataions and aggregations in modeling so it is important to identify that it is there so we can decide to eliminate, alter, or leave it going forward.

# %% [markdown]
# # Task VI

# %%
string = 'Data Mining Expert'
print(string)
# Out:
# Data Mining Expert

# %%
secound_string = ['cat','dog','snail','snake','rabbit']
print(secound_string[2])
# Out:
# snail

# %% [markdown]
# # Save to HTML

# %%
# Insert a code cell to include to following line of command in each
# Colab notebook to access data files saved in Google Drive of your account
# Retrieve csv file from google drive by mapping the folder from google drive.
# Must be done each time session expires.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# copy the ipynb to the local working directory
# This file name must change to be the name of your Lab file!
# !cp "/content/drive/MyDrive/Colab Notebooks/A1_Messier_Mitch.ipynb" ./

# create html from ipynb
# !jupyter nbconvert --to html "A1_Messier_Mitch.ipynb"
# Out:
# [NbConvertApp] Converting notebook A1_Messier_Mitch.ipynb to html
# [NbConvertApp] Writing 647768 bytes to A1_Messier_Mitch.html
